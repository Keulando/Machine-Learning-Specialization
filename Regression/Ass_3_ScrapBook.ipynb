# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt 
# %matplotlib notebook

# %%
dtype_dict = {'bathrooms':float, 'waterfront':int, 'sqft_above':int, 'sqft_living15':float, 'grade':int, 'yr_renovated':int, 'price':float, 'bedrooms':float, 'zipcode':str, 'long':float, 'sqft_lot15':float, 'sqft_living':float, 'floors':str, 'condition':int, 'lat':float, 'date':str, 'sqft_basement':int, 'yr_built':int, 'id':str, 'sqft_lot':int, 'view':int}

# %%
sales= pd.read_csv('kc_house_data.csv', dtype=dtype_dict)
sales= sales.sort_values(by=['sqft_living','price'])

# %%
def polynom_df(feature, degrees):
    # degree >=1
    poly_df=pd.DataFrame()
    poly_df['price']=sales['price']
    poly_df['power_1']=feature
    
    #cehck if degree >1
    if degree in degrees > 1:
        for power in range(2, degree+1): #loop over reaming deg
            name = 'power_'+str(power)
            poly_df[name]=poly_df['power_1'].apply(lambda x: x**power)
            
    return poly_df

# %%
def model_prediction(target):
    for column in poly_df.columns:
        X=poly_df[column].reshape(-1,1)
        y=poly_df[target]
        model=LinearRegression().fit(X,y)
        prediction=model.predict(X)
    return prediction

# %%
poly_df=polynom_df(sales['sqft_living'],degrees=[1,2,3])
predictions=model_prediction('price')
poly_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-a875b416b75c> in <module>()
# ----> 1 poly_df=polynom_df(sales['sqft_living'],degrees=[1,2,3])
#       2 predictions=model_prediction('price')
#       3 poly_df
#
# <ipython-input-41-3f2dcf907192> in polynom_df(feature, degrees)
#       6
#       7     #cehck if degree >1
# ----> 8     if degree in degrees > 1:
#       9         for power in range(2, degree+1): #loop over reaming deg
#      10             name = 'power_'+str(power)
#
# NameError: name 'degree' is not defined

# %%
def plot_degrees(degrees, feature, target):
    for degree in degrees:
        poly_df=polynom_df(feature,degree=degree)
        predictions=model_prediction(target)
        
    return plt.plot(poly_df.columns[1], poly_df.columns[0], '.',
                        poly_df.columns[1], predictions.reshape(1,-1), '-')

# %%
plot_degrees([1,2,3],feature=sales['sqft_living'], target='price')
# Out:
# C:\Users\Keulando\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   This is separate from the ipykernel package so we can avoid doing imports until
# <img src="data:image/png;base64,..." width="639.4710340596957">
# ...
#  ...]

# %%
degrees=[1,2,3,4]
for degree in degrees:
    poly_df=polynom_df(sales['sqft_living'],degree=degree)

# %%
poly_df.columns[0]
# Out:
# 'price'

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
poly15_sub_2= poly_df(sub_2['sqft_living'],degree=15)
poly15_sub_2['price']=sub_2['price']
#output variable

X=poly15_sub_2['power_15'].reshape(-1,1)
y=poly15_sub_2['price']
model15_sub_2=LinearRegression().fit(X,y)

pred15_sub_2=model15_sub_2.predict(X)

fig15_sub_2, ax15_sub_2 = plt.subplots()
ax15_sub_2.plot(poly15_sub_2['power_1'], poly15_sub_2['price'], '.',
        poly15_sub_2['power_1'], pred15_sub_2, '-')

coeff_sub_2=Coeff(model15_sub_2,15)

# %%
def poly_df(feature, degree):
    # degree >=1
    
    poly_df=pd.DataFrame()
    poly_df['power_1']=feature
    
    #cehck if degree >1
    if degree > 1:
        for power in range(2, degree+1): #loop over reaming deg
            name = 'power_'+str(power)
            poly_df[name]=poly_df['power_1'].apply(lambda x: x**power)
            
    return poly_df

# %%
poly2_data= poly_df(sales['sqft_living'],degree=2)
poly2_data['price']=sales['price']
#output variable

# %%
poly2_data[['power_1','power_2']]
# Out:
#        power_1      power_2
# 19452    290.0      84100.0
# 15381    370.0     136900.0
# 860      380.0     144400.0
# 18379    384.0     147456.0
# 4868     390.0     152100.0
# 21332    390.0     152100.0
# 8623     410.0     168100.0
# 11500    420.0     176400.0
# 14466    420.0     176400.0
# 465      430.0     184900.0
# 1168     440.0     193600.0
# 18052    460.0     211600.0
# 12075    470.0     220900.0
# 15248    470.0     220900.0
# 17394    480.0     230400.0
# 8133     480.0     230400.0
# 4203     490.0     240100.0
# 4651     500.0     250000.0
# 2141     520.0     270400.0
# 3223     520.0     270400.0
# 18059    520.0     270400.0
# 2930     520.0     270400.0
# 6779     520.0     270400.0
# 9641     520.0     270400.0
# 12484    530.0     280900.0
# 3582     530.0     280900.0
# 7017     530.0     280900.0
# 14450    540.0     291600.0
# 12757    540.0     291600.0
# 18508    550.0     302500.0
# ...        ...          ...
# 12872   6980.0   48720400.0
# ...

# %%
X=poly2_data[['power_1','power_2']]
y=poly2_data['price']

# %%
X
# Out:
#        power_1      power_2
# 19452    290.0      84100.0
# 15381    370.0     136900.0
# 860      380.0     144400.0
# 18379    384.0     147456.0
# 4868     390.0     152100.0
# 21332    390.0     152100.0
# 8623     410.0     168100.0
# 11500    420.0     176400.0
# 14466    420.0     176400.0
# 465      430.0     184900.0
# 1168     440.0     193600.0
# 18052    460.0     211600.0
# 12075    470.0     220900.0
# 15248    470.0     220900.0
# 17394    480.0     230400.0
# 8133     480.0     230400.0
# 4203     490.0     240100.0
# 4651     500.0     250000.0
# 2141     520.0     270400.0
# 3223     520.0     270400.0
# 18059    520.0     270400.0
# 2930     520.0     270400.0
# 6779     520.0     270400.0
# 9641     520.0     270400.0
# 12484    530.0     280900.0
# 3582     530.0     280900.0
# 7017     530.0     280900.0
# 14450    540.0     291600.0
# 12757    540.0     291600.0
# 18508    550.0     302500.0
# ...        ...          ...
# 12872   6980.0   48720400.0
# ...

# %%
def Coeff(x,power, debug=False):
    '''Prints intercept and coeff in a better format
    
    args: x= name of model
          power= degree of polynomial function'''
    
    names=["intercept",'power_'+str(power)]
    values=[x.intercept_,x.coef_]
    df=pd.DataFrame(columns=['Name','Value'])
    df['Name']=names
    df['Value']= values
    if debug ==True:
        print('coef is/are: {:.4f}'.format(x.coef_))
        print('intercept is: {:.4f}'.format(x.intercept_))
    return df

# %%
coef_df=pd.DataFrame()
coef_df=coef_df.append({"Name":'Intercept', 'Value':23}, ignore_index=True)
#coef_df=coef_df.append({'Name':'Power_1'}, ignore_index=True)
coef_df
# Out:
#         Name  Value
# 0  Intercept   23.0

# %%
# Out:
# C:\Users\Keulando\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
coef_df
# Out:
#   Name  Value
# 0   we   23.0

# %%
def poly_df(feature, degree):
    # degree >=1
    
    poly_df=pd.DataFrame()
    poly_df['price']=sales['price']
    poly_df['power_1']=feature
    
    #cehck if degree >1
    if degree > 1:
        for power in range(2, degree+1): #loop over reaming deg
            name = 'power_'+str(power)
            poly_df[name]=poly_df['power_1'].apply(lambda x: x**power)
            
    return poly_df

# %%
poly=poly_df(sales['sqft_living'], 3)

# %%
list(poly.columns[1:])
# Out:
# ['power_1', 'power_2', 'power_3']

# %%
def poly_df_for_subs(feature, subset, degree):
    # degree >=1
    
    poly_df=pd.DataFrame()
    poly_df['price']=subset['price']
    poly_df['power_1']=subset[str(feature)]
    
    #cehck if degree >1
    if degree > 1:
        for power in range(2, degree+1): #loop over reaming deg
            name = 'power_'+str(power)
            poly_df[name]=poly_df['power_1'].apply(lambda x: x**power)
            
    return poly_df

# %%
def Coeff2(x, power):
    '''Prints intercept and coeff in a better format
    
    args: x = name of model
      power = degree of polynomial function'''
    
    coef_df=pd.DataFrame()
    coef_df=coef_df.append({"Name":'Intercept', 'Value':x.intercept_}, ignore_index=True)
    coef_df=coef_df.append({'Name':'Power_1','Value':x.coef_[0]}, ignore_index=True)
    
    if power > 1:
        for power in range(2, power+1):
            name= 'Power_' + str(power)
            coef_df=coef_df.append({"Name":name, 'Value':'{:.3e}'.format(x.coef_[power-1])}, ignore_index=True)
    
    return coef_df

# %%
poly15_sub_1= poly_df_for_subs('sqft_living',sub_1, degree= 15)


features=list(poly15_sub_1.columns[1:])
X=poly15_sub_1[features]
y=poly15_sub_1['price']
model15_sub_1=LinearRegression().fit(X,y)

pred15_sub_1=model15_sub_1.predict(X)

fig15_sub_1, ax15_sub_1 = plt.subplots()
ax15_sub_1.plot(poly15_sub_1['power_1'], poly15_sub_1['price'], '.',
        poly15_sub_1['power_1'], pred15_sub_1, '-')

coeff_sub_1=Coeff2(model15_sub_1,15)
Coeff2(model15_sub_1, 15)
# Out:
# <img src="data:image/png;base64,..." width="639.4710340596957">
#          Name        Value
# 0   Intercept       539059
# 1     Power_1  3.05794e-90
# 2     Power_2   -1.694e-49
# 3     Power_3   -5.618e-55
# 4     Power_4   -4.978e-60
# 5     Power_5    0.000e+00
# 6     Power_6    1.104e-70
# 7     Power_7    8.377e-67
# 8     Power_8    6.234e-63
# 9     Power_9    4.492e-59
# 10   Power_10    3.069e-55
# 11   Power_11    1.917e-51
# 12   Power_12    1.013e-47
# 13   Power_13    3.622e-44
# 14   Power_14   -5.635e-48
# 15   Power_15    2.186e-52

# %%
fig15_sub_1, ax15_sub_1 = plt.subplots()
ax15_sub_1.plot(poly15_sub_1['power_1'], poly15_sub_1['price'], '.',
        poly15_sub_1['power_1'], pred15_sub_1, '-')

# %%
sub_1=pd.read_csv('wk3_kc_house_set_1_data.csv', dtype=dtype_dict)
sub_2=pd.read_csv('wk3_kc_house_set_2_data.csv', dtype=dtype_dict)
sub_3=pd.read_csv('wk3_kc_house_set_3_data.csv', dtype=dtype_dict)
sub_4=pd.read_csv('wk3_kc_house_set_4_data.csv', dtype=dtype_dict)

# %%
def prep_model_and_predict(feature, target, degree, plot, *datasets):
    

    
    # part 1: make a df with relevant format and features 
        # degree >=1
    for dataset in datasets:
        poly_df=pd.DataFrame()
        poly_df[str(target)] = dataset[str(target)]
        poly_df['power_1']   = dataset[str(feature)]
    
        #cehck if degree >1
        if degree > 1:
            for power in range(2, degree+1): #loop over reaming deg
                name = 'power_'+str(power)
                poly_df[name]=poly_df['power_1'].apply(lambda x: x**power)
            
    #part 2: make model and predictions
    
        features=list(poly_df.columns[1:])
        X=poly_df[features]
        y=poly_df[str(target)]
        model=LinearRegression().fit(X,y)
        predictions=model.predict(X)
    
    #part 3: put weghts in a nice df
    
        coef_df=pd.DataFrame()
        coef_df=coef_df.append({"Name":'Intercept', 'Value':model.intercept_}, ignore_index=True)
        coef_df=coef_df.append({'Name':'Power_1',   'Value':model.coef_[0]},   ignore_index=True)
    
        if degree > 1:
            for degree in range(2, degree+1):
                name = 'Power_' + str(degree)
                coef_df = coef_df.append({"Name":name, 
                                          'Value':'{:.3e}'.format(model.coef_[degree-1])}, ignore_index=True)
                #print(coef_df)
    #prt 4: plot it
        if plot == True:
            plt.figure()
            plt.plot(poly_df['power_1'], poly_df[str(target)], '.',
                    poly_df['power_1'], predictions, '-')

            plt.xlabel('Square footage, living area')
            plt.ylabel('Price per Sqft')
            plt.ticklabel_format(axis='y', style='sci', scilimits=(-2,2))
            plt.show()
    return coef_df, predictions, model

# %%
X
# Out:
#       power_1      power_2       power_3       power_4       power_5  \
# 0       430.0     184900.0  7.950700e+07  3.418801e+10  1.470084e+13
# 1       460.0     211600.0  9.733600e+07  4.477456e+10  2.059630e+13
# 2       470.0     220900.0  1.038230e+08  4.879681e+10  2.293450e+13
# 3       490.0     240100.0  1.176490e+08  5.764801e+10  2.824752e+13
# 4       500.0     250000.0  1.250000e+08  6.250000e+10  3.125000e+13
# 5       520.0     270400.0  1.406080e+08  7.311616e+10  3.802040e+13
# 6       520.0     270400.0  1.406080e+08  7.311616e+10  3.802040e+13
# 7       520.0     270400.0  1.406080e+08  7.311616e+10  3.802040e+13
# 8       550.0     302500.0  1.663750e+08  9.150625e+10  5.032844e+13
# 9       560.0     313600.0  1.756160e+08  9.834496e+10  5.507318e+13
# 10      570.0     324900.0  1.851930e+08  1.055600e+11  6.016921e+13
# 11      580.0     336400.0  1.951120e+08  1.131650e+11  6.563568e+13
# 12      580.0     336400.0  1.951120e+08  1.131650e+11  6.563568e+13
# ...

# %%
plot=prep_model_and_predict('sqft_living','price', 15, False, sub_1)[2]
plot.predict(X)
# Out:
# array([  539058.81866848,   539058.81866848,   539058.81866848, ...,
#         6477904.6552251 ,  7652130.80374937,  2285683.27956006])

# %%
fpp
# Out:
#          Name        Value
# 0   Intercept       539059
# 1     Power_1  3.05794e-90
# 2     Power_2   -1.694e-49
# 3     Power_3   -5.618e-55
# 4     Power_4   -4.978e-60
# 5     Power_5    0.000e+00
# 6     Power_6    1.104e-70
# 7     Power_7    8.377e-67
# 8     Power_8    6.234e-63
# 9     Power_9    4.492e-59
# 10   Power_10    3.069e-55
# 11   Power_11    1.917e-51
# 12   Power_12    1.013e-47
# 13   Power_13    3.622e-44
# 14   Power_14   -5.635e-48
# 15   Power_15    2.186e-52

# %%
plot
# Out:
#           price  power_1      power_2       power_3       power_4  \
# 0       80000.0    430.0     184900.0  7.950700e+07  3.418801e+10
# 1      247000.0    460.0     211600.0  9.733600e+07  4.477456e+10
# 2      192500.0    470.0     220900.0  1.038230e+08  4.879681e+10
# 3      150000.0    490.0     240100.0  1.176490e+08  5.764801e+10
# 4      125000.0    500.0     250000.0  1.250000e+08  6.250000e+10
# 5       82500.0    520.0     270400.0  1.406080e+08  7.311616e+10
# 6      275000.0    520.0     270400.0  1.406080e+08  7.311616e+10
# 7      330000.0    520.0     270400.0  1.406080e+08  7.311616e+10
# 8      353000.0    550.0     302500.0  1.663750e+08  9.150625e+10
# 9      299000.0    560.0     313600.0  1.756160e+08  9.834496e+10
# 10      89950.0    570.0     324900.0  1.851930e+08  1.055600e+11
# 11     220000.0    580.0     336400.0  1.951120e+08  1.131650e+11
# 12     330600.0    580.0     336400.0  1.951120e+08  1.131650e+11
# ...

# %%
# i wanna pass degree as a list and iterate over it
